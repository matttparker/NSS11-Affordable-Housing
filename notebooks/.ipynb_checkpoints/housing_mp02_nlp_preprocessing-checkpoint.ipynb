# %%
from sqlalchemy import create_engine
import pandas as pd
import plotly.graph_objects as go
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import re
import nltk
import matplotlib.pyplot as plt

# %%
connection_housing = "postgres://postgres:postgres@localhost:5432/housing"

# %%
engine = create_engine(connection_housing)

# %%
query1 = '''
SELECT p.apn, p.permittype, p.permitsubtype, p.dateissued, p.purpose, p.contractor, pu.propzip
FROM permit AS p
INNER JOIN property_updated AS pu
USING (apn)
WHERE p.status NOT IN ('EXPIRED'
    , 'REJECTED'
    , 'PENDING'
    , 'WITHDRAWN'
    , 'CNCL'
    , 'REFUNDED'
    , 'NOT GRANTD'
    , 'REVOKED'
    , 'CHANCERY'
    , 'INREVIEW'
    , 'REQUESTED'
    , 'IGNORE')
AND pu.ludesc IN ('SINGLE FAMILY'
    , 'RESIDENTIAL CONDO'
    , 'APARTMENT: HIGH RISE (3 STORIES OR GREATER)'
    , 'APARTMENT: LOW RISE (BUILT SINCE 1960)'
    , 'APARTMENT: WALK UP (BUILT PRIOR TO 1960)'
    , 'DUPLEX'
    , 'TRIPLEX'
    , 'QUADPLEX'
    , 'ZERO LOT LINE'
    , 'VACANT RESIDENTIAL LAND'
    , 'MOBILE HOME PARK')
AND p.dateissued >= '2008-01-01'
'''

test = pd.read_sql(query1, con = engine)

# %%
test.shape
# Out:
# (357388, 7)

# %%
test.head(50)
# Out:
#                apn                        permittype  \
# 0      13209013100                 ELECTRICAL PERMIT
# 1      13209015600                 ELECTRICAL PERMIT
# 2      13209015600                 ELECTRICAL PERMIT
# 3      13209015600   GAS / MECH UP TO 1500 BTUS - HC
# 4      13209015600                 ELECTRICAL PERMIT
# 5      13209015600         GAS / MECH PERMIT - VC MC
# 6      13209015600             CODES PLUMBING PERMIT
# 7      13209015600                 ELECTRICAL PERMIT
# 8   132090F00200CO             CODES PLUMBING PERMIT
# 9   132090F00200CO     ELECTRICAL LOW VOLTAGE PERMIT
# 10  132090F00200CO                 ELECTRICAL PERMIT
# 11  132090F00200CO             CODES PLUMBING PERMIT
# 12  132090F00200CO         GAS / MECH PERMIT - VC MC
# 13  132090O00100CO   GAS / MECH UP TO 1500 BTUS - HC
# 14  132090O00100CO             CODES PLUMBING PERMIT
# 15  132090F00200CO                 ELECTRICAL PERMIT
# 16  132090F00200CO        BUILDING RESIDENTIAL - NEW
# 17  132090G00200CO   GAS / MECH UP TO 1500 BTUS - HC
# 18  132090I00100CO             CODES PLUMBING PERMIT
# 19  132090I00100CO        BUILDING RESIDENTIAL - NEW
# 20  132090L00200CO                 ELECTRICAL PERMIT
# 21  132090L00200CO             CODES PLUMBING PERMIT
# 22  132090L00200CO     ELECTRICAL LOW VOLTAGE PERMIT
# 23  132090L00200CO  ELECTRICAL SECURITY ALARM PERMIT
# 24  132090L00200CO                 ELECTRICAL PERMIT
# 25  132090L00200CO             CODES PLUMBING PERMIT
# 26  132090L00200CO    GAS / MECH UP TO 750 BTUS - AC
# 27  132090O00100CO             CODES PLUMBING PERMIT
# 28  132090L00200CO   GAS / MECH UP TO 1500 BTUS - HC
# 29  132090M00200CO             CODES PLUMBING PERMIT
# 30  132090M00200CO  ELECTRICAL SECURITY ALARM PERMIT
# 31  132090M00200CO         GAS / MECH PERMIT - VC MC
# 32  132090M00200CO             CODES PLUMBING PERMIT
# 33  132090M00200CO    GAS / MECH UP TO 750 BTUS - AC
# 34  132090M00200CO                 ELECTRICAL PERMIT
# 35  132090M00200CO                 ELECTRICAL PERMIT
# 36  132090M00200CO        BUILDING RESIDENTIAL - NEW
# 37  132090O00100CO      BUILDING RESIDENTIAL - REHAB
# 38  132090R00100CO                 ELECTRICAL PERMIT
# 39  132090R00100CO                 ELECTRICAL PERMIT
# 40  132090R00100CO    GAS / MECH UP TO 750 BTUS - AC
# 41  132090R00100CO             CODES PLUMBING PERMIT
# 42  132090R00100CO                 ELECTRICAL PERMIT
# 43  132090R00100CO        BUILDING RESIDENTIAL - NEW
# 44  132090R00200CO             CODES PLUMBING PERMIT
# 45  132090R00200CO         GAS / MECH PERMIT - VC MC
# 46  132090R00200CO  ELECTRICAL SECURITY ALARM PERMIT
# 47  132090R00200CO             CODES PLUMBING PERMIT
# 48     06912005900                 ELECTRICAL PERMIT
# 49     06912005900                 ELECTRICAL PERMIT
#
#                          permitsubtype  dateissued  \
# 0                ELECT SERVICE RELEASE  2020-07-13
# 1               FULL ELECTRICAL PERMIT  2014-12-09
# 2                ELECT SERVICE RELEASE  2014-12-09
# 3   GAS / MECH PERMIT (UP TO 1500 BTU)  2014-10-23
# 4               FULL ELECTRICAL PERMIT  2014-10-23
# 5                    GAS / MECH PERMIT  2014-09-30
# 6                      PLUMBING PERMIT  2014-08-14
# 7               TEMPORARY ELEC SERVICE  2014-07-11
# 8                      PLUMBING PERMIT  2011-12-08
# 9                                 None  2011-11-09
# 10              FULL ELECTRICAL PERMIT  2011-11-07
# 11                     PLUMBING PERMIT  2011-11-04
# 12                   GAS / MECH PERMIT  2011-10-31
# 13  GAS / MECH PERMIT (UP TO 1500 BTU)  2016-07-15
# 14                     PLUMBING PERMIT  2016-06-22
# 15              TEMPORARY ELEC SERVICE  2011-10-18
# 16             SINGLE FAMILY RESIDENCE  2011-09-29
# 17  GAS / MECH PERMIT (UP TO 1500 BTU)  2012-11-26
# 18                     PLUMBING PERMIT  2013-08-28
# 19               MULTIFAMILY, TOWNHOME  2013-06-14
# 20               ELECT SERVICE RELEASE  2014-12-29
# 21                     PLUMBING PERMIT  2014-10-21
# 22                                None  2014-09-29
# 23                                None  2014-09-18
# 24              FULL ELECTRICAL PERMIT  2014-09-15
# 25                     PLUMBING PERMIT  2014-08-28
# 26   GAS / MECH PERMIT (UP TO 750 BTU)  2014-08-28
# 27                     PLUMBING PERMIT  2020-01-24
# 28  GAS / MECH PERMIT (UP TO 1500 BTU)  2014-08-14
# 29                     PLUMBING PERMIT  2015-11-23
# 30                                None  2015-09-30
# 31                   GAS / MECH PERMIT  2015-09-24
# 32                     PLUMBING PERMIT  2015-09-21
# 33   GAS / MECH PERMIT (UP TO 750 BTU)  2015-09-21
# 34               ELECT SERVICE RELEASE  2015-09-21
# 35              FULL ELECTRICAL PERMIT  2015-09-21
# 36             SINGLE FAMILY RESIDENCE  2015-06-17
# 37             SINGLE FAMILY RESIDENCE  2020-01-06
# 38               ELECT SERVICE RELEASE  2019-10-21
# 39              FULL ELECTRICAL PERMIT  2019-10-21
# 40   GAS / MECH PERMIT (UP TO 750 BTU)  2019-10-16
# 41                     PLUMBING PERMIT  2019-08-07
# 42              TEMPORARY ELEC SERVICE  2019-06-25
# 43             SINGLE FAMILY RESIDENCE  2019-05-24
# 44                     PLUMBING PERMIT  2020-04-13
# 45                   GAS / MECH PERMIT  2019-11-26
# 46                                None  2019-11-25
# 47                     PLUMBING PERMIT  2019-11-18
# 48               ELECT SERVICE RELEASE  2010-09-27
# 49              FULL ELECTRICAL PERMIT  2010-08-24
#
#                                               purpose  \
# 0                    NEW RESIDENTIAL CITY OF OAK HILL
# 1   12/9/14- MRP- EXISTING, RESIDENTIAL, ADDING PO...
# 2   OAK HILL BP # 4987   FULL PERMIT #2006526 THAT...
# 3   OAK HILL PERMIT\r\n(2) WOOD-BURNING FIREPLACES...
# 4   OAK HILL BUILDING PERMIT #4987 \r\n\r\nNEED FU...
# 5   INSTALL NEW HVAC SYSTEMS WITH DUCT WORK AND GA...
# 6   INSTALL COMPLETE PLUMBING SYSTEM IN NEW CONSTR...
# 7   NEED A 60 TEMP PERMIT FOR NEW CONSTRUCTION\r\n...
# 8   TO CONSTRUCT A 3083 SQ FT 2 STORY SINGLE FAMIL...
# 9   TO CONSTRUCT A 3083 SQ FT 2 STORY SINGLE FAMIL...
# 10  NEW WIRING OF RESIDENCE- TO CONSTRUCT A 3083 S...
# 11  TO CONSTRUCT A 3083 SQ FT 2 STORY SINGLE FAMIL...
# 12  NEW CONSTRUCTION - INSTALL 2.5 TON GAS PACKAGE...
# 13        WOOD BURNING FIREPLACE WITH GAS STARTER KIT
# 14                               WHOLE HOUSE PLUMBING
# 15  TEMPORARY ELECTRICAL SERVICE- TO CONSTRUCT A 3...
# 16  TO CONSTRUCT A 3083 SQ FT 2 STORY SINGLE FAMIL...
# 17  CONSTRUCT 2968 SF SGL FAM TOWNHOME W/576 SF AT...
# 18  FOR EVERY 30 FEET OF STREET FRONTAGE, OR FRACT...
# 19  FOR EVERY 30 FEET OF STREET FRONTAGE, OR FRACT...
# 20  SERVICE RELEASE- TO CONSTRUCT 3565 SF TWO STOR...
# 21  TO CONSTRUCT 3565 SF TWO STORY SINGLE FAMILY R...
# 22  TO CONSTRUCT 3565 SF TWO STORY SINGLE FAMILY R...
# 23                  PREWIRE FOR SECURITY ALARM SYSTEM
# 24  WIRING OF NEW RESIDENCE-  TO CONSTRUCT 3565 SF...
# 25  TO CONSTRUCT 3565 SF TWO STORY SINGLE FAMILY R...
# 26                         FIREPLACE INSTALLATION\r\n
# 27  BUILD OUTDOOR KITCHEN & GAS FIREPLACE. CONVERT...
# 28  TO CONSTRUCT 3565 SF TWO STORY SINGLE FAMILY R...
# 29  PURSUANT # 2006-1263  METRO CODE OF LAWS, I (H...
# 30  PURSUANT # 2006-1263  METRO CODE OF LAWS, I (H...
# 31  PURSUANT # 2006-1263  METRO CODE OF LAWS, I (H...
# 32  PURSUANT # 2006-1263  METRO CODE OF LAWS, I (H...
# 33                            FIREPLACE INSTALLATION.
# 34  PURSUANT # 2006-1263  METRO CODE OF LAWS, I (H...
# 35  PURSUANT # 2006-1263  METRO CODE OF LAWS, I (H...
# 36  PURSUANT # 2006-1263  METRO CODE OF LAWS, I (H...
# 37  BUILD OUTDOOR KITCHEN & GAS FIREPLACE. CONVERT...
# 38  TO CONSTRUCT 935 GLENDALE LANE OF NEW HPR/DUPL...
# 39  TO CONSTRUCT 935 GLENDALE LANE OF NEW HPR/DUPL...
# 40  TO CONSTRUCT 935 GLENDALE LANE OF NEW HPR/DUPL...
# 41  TO CONSTRUCT 935 GLENDALE LANE OF NEW HPR/DUPL...
# 42  TO CONSTRUCT 935 GLENDALE LANE OF NEW HPR/DUPL...
# 43  TO CONSTRUCT 935 GLENDALE LANE OF NEW HPR/DUPL...
# 44  TO CONSTRUCT 937 GLENDALE LANE OF NEW HPR/DUPL...
# 45  TO CONSTRUCT 937 GLENDALE LANE OF NEW HPR/DUPL...
# 46  TO CONSTRUCT 937 GLENDALE LANE OF NEW HPR/DUPL...
# 47  TO CONSTRUCT 937 GLENDALE LANE OF NEW HPR/DUPL...
# 48                                    SERVICE RELEASE
# 49  REPAIR FIRE DAMAGED SINGLE FAMILY RES....NO NE...
#
#                                            contractor  propzip
# 0                                  CARDWELLS ELECTRIC    37220
# 1                                Winston Electric Llc    37220
# 2                                 Empire Electric Llc    37220
# 3                Nashville Fireplace Distributors Inc    37220
# 4                                 Empire Electric Llc    37220
# 5                                   Frick, M J Co Inc    37220
# 6                                  G & M Plumbing Llc    37220
# 7                                 Empire Electric Llc    37220
# 8                              Benchmark Plumbing Inc    37204
# 9                                Reha Enterprises Llc    37204
# 10   Morgan, Michael J Dba Mr. Sparky  Nashville-East    37204
# 11                             Benchmark Plumbing Inc    37204
# 12    Roscoe Brown Heating & Cooling Of Nashville Inc    37204
# 13               NASHVILLE FIREPLACE DISTRIBUTORS INC    37220
# 14                                  FRICK, M J CO INC    37220
# 15   Morgan, Michael J Dba Mr. Sparky  Nashville-East    37204
# 16                              Rigid Development Inc    37204
# 17                                C & D Heating & A/C    37204
# 18                                 Myers Plumbing Inc    37220
# 19  Parkside Builders Llc  ( Formerly Cute Cottage...    37220
# 20   Morgan, Michael J Dba Mr. Sparky  Nashville-East    37204
# 21                             Dove Construction, Llc    37204
# 22                                   Max Electric Inc    37204
# 23                     Superior Detection Systems Inc    37204
# 24   Morgan, Michael J Dba Mr. Sparky  Nashville-East    37204
# 25                  Hasty, Paul & Son Plumbing Co Inc    37204
# 26                                      Fireworks Inc    37204
# 27                  HASTY, PAUL & SON PLUMBING CO INC    37220
# 28                     Franklin Heating & Cooling Inc    37204
# 29             Kimbrough, Dale M Plbg/Backhoe Service    37204
# 30                      Guardian Security Systems Inc    37204
# 31                          Reliance Heating & Air Co    37204
# 32                            Powerhouse Plumbing Inc    37204
# 33                                      Fireworks Inc    37204
# 34                              Felix Enterprises Inc    37204
# 35                              Felix Enterprises Inc    37204
# 36                          Cadence Construction, Llc    37204
# 37                         WHITESTONE ENTERPRISES LLC    37220
# 38                                            DEC LLC    37204
# 39                                            DEC LLC    37204
# 40                                           DALE INC    37204
# 41                              RHODES, JOSH PLUMBING    37204
# 42                                            DEC LLC    37204
# 43                       HALLMARK BUILDING GROUP, INC    37204
# 44                          JURISIN, TIM PLUMBING INC    37204
# 45                          RELIANCE HEATING & AIR CO    37204
# 46                      GUARDIAN SECURITY SYSTEMS INC    37204
# 47                              RHODES, JOSH PLUMBING    37204
# 48                                         G Electric    37218
# 49                                         G Electric    37218

# %%
permits = test.dropna()

# %%
permits.head(20)
# Out:
#                apn                       permittype  \
# 0      13209013100                ELECTRICAL PERMIT
# 1      13209015600                ELECTRICAL PERMIT
# 2      13209015600                ELECTRICAL PERMIT
# 3      13209015600  GAS / MECH UP TO 1500 BTUS - HC
# 4      13209015600                ELECTRICAL PERMIT
# 5      13209015600        GAS / MECH PERMIT - VC MC
# 6      13209015600            CODES PLUMBING PERMIT
# 7      13209015600                ELECTRICAL PERMIT
# 8   132090F00200CO            CODES PLUMBING PERMIT
# 10  132090F00200CO                ELECTRICAL PERMIT
# 11  132090F00200CO            CODES PLUMBING PERMIT
# 12  132090F00200CO        GAS / MECH PERMIT - VC MC
# 13  132090O00100CO  GAS / MECH UP TO 1500 BTUS - HC
# 14  132090O00100CO            CODES PLUMBING PERMIT
# 15  132090F00200CO                ELECTRICAL PERMIT
# 16  132090F00200CO       BUILDING RESIDENTIAL - NEW
# 17  132090G00200CO  GAS / MECH UP TO 1500 BTUS - HC
# 18  132090I00100CO            CODES PLUMBING PERMIT
# 19  132090I00100CO       BUILDING RESIDENTIAL - NEW
# 20  132090L00200CO                ELECTRICAL PERMIT
#
#                          permitsubtype  dateissued  \
# 0                ELECT SERVICE RELEASE  2020-07-13
# 1               FULL ELECTRICAL PERMIT  2014-12-09
# 2                ELECT SERVICE RELEASE  2014-12-09
# 3   GAS / MECH PERMIT (UP TO 1500 BTU)  2014-10-23
# 4               FULL ELECTRICAL PERMIT  2014-10-23
# 5                    GAS / MECH PERMIT  2014-09-30
# 6                      PLUMBING PERMIT  2014-08-14
# 7               TEMPORARY ELEC SERVICE  2014-07-11
# 8                      PLUMBING PERMIT  2011-12-08
# 10              FULL ELECTRICAL PERMIT  2011-11-07
# 11                     PLUMBING PERMIT  2011-11-04
# 12                   GAS / MECH PERMIT  2011-10-31
# 13  GAS / MECH PERMIT (UP TO 1500 BTU)  2016-07-15
# 14                     PLUMBING PERMIT  2016-06-22
# 15              TEMPORARY ELEC SERVICE  2011-10-18
# 16             SINGLE FAMILY RESIDENCE  2011-09-29
# 17  GAS / MECH PERMIT (UP TO 1500 BTU)  2012-11-26
# 18                     PLUMBING PERMIT  2013-08-28
# 19               MULTIFAMILY, TOWNHOME  2013-06-14
# 20               ELECT SERVICE RELEASE  2014-12-29
#
#                                               purpose  \
# 0                    NEW RESIDENTIAL CITY OF OAK HILL
# 1   12/9/14- MRP- EXISTING, RESIDENTIAL, ADDING PO...
# 2   OAK HILL BP # 4987   FULL PERMIT #2006526 THAT...
# 3   OAK HILL PERMIT\r\n(2) WOOD-BURNING FIREPLACES...
# 4   OAK HILL BUILDING PERMIT #4987 \r\n\r\nNEED FU...
# 5   INSTALL NEW HVAC SYSTEMS WITH DUCT WORK AND GA...
# 6   INSTALL COMPLETE PLUMBING SYSTEM IN NEW CONSTR...
# 7   NEED A 60 TEMP PERMIT FOR NEW CONSTRUCTION\r\n...
# 8   TO CONSTRUCT A 3083 SQ FT 2 STORY SINGLE FAMIL...
# 10  NEW WIRING OF RESIDENCE- TO CONSTRUCT A 3083 S...
# 11  TO CONSTRUCT A 3083 SQ FT 2 STORY SINGLE FAMIL...
# 12  NEW CONSTRUCTION - INSTALL 2.5 TON GAS PACKAGE...
# 13        WOOD BURNING FIREPLACE WITH GAS STARTER KIT
# 14                               WHOLE HOUSE PLUMBING
# 15  TEMPORARY ELECTRICAL SERVICE- TO CONSTRUCT A 3...
# 16  TO CONSTRUCT A 3083 SQ FT 2 STORY SINGLE FAMIL...
# 17  CONSTRUCT 2968 SF SGL FAM TOWNHOME W/576 SF AT...
# 18  FOR EVERY 30 FEET OF STREET FRONTAGE, OR FRACT...
# 19  FOR EVERY 30 FEET OF STREET FRONTAGE, OR FRACT...
# 20  SERVICE RELEASE- TO CONSTRUCT 3565 SF TWO STOR...
#
#                                            contractor  propzip
# 0                                  CARDWELLS ELECTRIC    37220
# 1                                Winston Electric Llc    37220
# 2                                 Empire Electric Llc    37220
# 3                Nashville Fireplace Distributors Inc    37220
# 4                                 Empire Electric Llc    37220
# 5                                   Frick, M J Co Inc    37220
# 6                                  G & M Plumbing Llc    37220
# 7                                 Empire Electric Llc    37220
# 8                              Benchmark Plumbing Inc    37204
# 10   Morgan, Michael J Dba Mr. Sparky  Nashville-East    37204
# 11                             Benchmark Plumbing Inc    37204
# 12    Roscoe Brown Heating & Cooling Of Nashville Inc    37204
# 13               NASHVILLE FIREPLACE DISTRIBUTORS INC    37220
# 14                                  FRICK, M J CO INC    37220
# 15   Morgan, Michael J Dba Mr. Sparky  Nashville-East    37204
# 16                              Rigid Development Inc    37204
# 17                                C & D Heating & A/C    37204
# 18                                 Myers Plumbing Inc    37220
# 19  Parkside Builders Llc  ( Formerly Cute Cottage...    37220
# 20   Morgan, Michael J Dba Mr. Sparky  Nashville-East    37204

# %%
permits.shape
# Out:
# (336497, 7)

# %%
pd.DataFrame(permits.purpose.value_counts(ascending=False).head(20)).reset_index()
# Out:
#                                                 index  purpose
# 0                                     SERVICE RELEASE      882
# 1                                       GAS FIREPLACE      871
# 2                                     HVAC CHANGE OUT      506
# 3                                        FLOOD DAMAGE      495
# 4                                         REPLACEMENT      473
# 5                              FIREPLACE INSTALLATION      470
# 6                                            PLUMBING      425
# 7                               GAS FIREPLACE\r\n\r\n      411
# 8                                   ROUGHIN AND FINAL      390
# 9                                        INSTALL HVAC      370
# 10                              NEW CONSTRUCTION HVAC      370
# 11                                               FULL      366
# 12  REHAB FLOOD DAMAGED RESIDENCE.   ***PURSUANT T...      340
# 13                              INSTALL GAS FIREPLACE      317
# 14                         FIREPLACE INSTALLATION\r\n      316
# 15  INSTALLATION OF TANKLESS WATER HEATER IN EXIST...      293
# 16  BY MAKING THIS APPLICATION FOR SHORT TERM RENT...      266
# 17                                        RAN SERVICE      248
# 18                                  GAS FIREPLACE\r\n      238
# 19  TO REHAB FLOOD DAMAGED RESIDENCE.  …………PURSUAN...      231

# %% [markdown]
# ## Find number of rows different words appear
# ### Trying to identify boilerplate language
