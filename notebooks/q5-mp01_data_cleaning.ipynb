# %% [markdown]
# # Get Model Data Imported and Cleaned

# %%
# import statements
import pandas as pd
from sqlalchemy import create_engine

# %%
# Set display options
pd.options.display.max_columns = 200
pd.options.display.max_rows = 500
pd.options.display.max_colwidth = None

# %%
# assign location of postgres database to a string
connection_string = "postgres://postgres:postgres@localhost:5432/housing"

# %%
# establish connection
engine = create_engine(connection_string)

# %% [markdown]
# ### Create assessments and permits dataframes
# *Per conversation on May 13, the data are limited to 1993 - 2021 for assessments and permits.*

# %%
assessments_query = '''
-- query to get all historical assessments for residences in Davidson county since 1993
WITH historicals AS (-- get historical assessment data for each property when it was residential 
	SELECT a.apn
		, a.effectivedate AS date
	-- also pull in the earliest address data we have for the apn
		, COALESCE(p.ludesc, pu.ludesc) AS prop_type
		, COALESCE(p.propaddr, pu.propaddr) AS prop_addr
		, COALESCE(p.propcity, pu.propcity) AS prop_city
		, COALESCE(p.propzip, pu.propzip) AS prop_zip
		, AVG(a.totalapprvalue) AS prop_value
		--, COALESCE(p.council, pu.council) AS prop_council
		--, COALESCE(p.taxdist, pu.taxdist) AS prop_taxdist

	FROM assessment AS a
	LEFT JOIN property AS p
		ON p.apn = a.apn
	LEFT JOIN property_updated AS pu
		ON pu.apn = a.apn
	
	WHERE a.classdesc = 'RESIDENTIAL' -- only get assessment data for properties when they were classified as residential
		AND a.effectivedate >= DATE('1993-01-01') -- only get data starting in 1993, when assessments regularized to every 4 years
		AND (-- only get apns that were counted as some form of residential property in 2017 or 2020;
			-- there are no apns that had more than one ludesc in either table, but a handful do change between tables
			p.ludesc IN (
				'SINGLE FAMILY'
				, 'RESIDENTIAL CONDO'
				, 'DUPLEX'
				, 'TRIPLEX'
				, 'QUADPLEX'
				, 'MOBILE HOME'
				)
			OR pu.ludesc IN (
				'SINGLE FAMILY'
				, 'RESIDENTIAL CONDO'
				, 'DUPLEX'
				, 'TRIPLEX'
				, 'QUADPLEX'
				, 'MOBILE HOME'
				)
			)
    
    GROUP BY 1,2,3,4,5,6
),

recents AS (-- get address and property type info for 2021 and any non-overlapping 2017 apns
	SELECT pu.apn
		, pu.assessdate AS date
		, pu.ludesc AS prop_type
		, pu.propaddr AS prop_addr
		, pu.propcity AS prop_city
		, pu.propzip AS prop_zip
        , AVG(pu.totlappr) AS prop_value
		--, pu.council AS prop_council
		--, pu.taxdist AS prop_taxdist
	
	FROM property_updated AS pu
	
	WHERE pu.ludesc IN (
		'SINGLE FAMILY'
		, 'RESIDENTIAL CONDO'
		, 'DUPLEX'
		, 'TRIPLEX'
		, 'QUADPLEX'
		, 'MOBILE HOME'
		)
    
    GROUP BY 1,2,3,4,5,6
	
	UNION -- drop duplicate rows, just in case they sneak in
	
	SELECT p.apn
		, p.assessdate AS date
		, p.ludesc AS prop_type
		, p.propaddr AS prop_addr
		, p.propcity AS prop_city
		, p.propzip AS prop_zip
		, AVG(p.totlappr) AS prop_value
		--, p.council AS prop_council
		--, p.taxdist AS prop_taxdist
	
	FROM property AS p
	
	WHERE p.ludesc IN (
		'SINGLE FAMILY'
		, 'RESIDENTIAL CONDO'
		, 'DUPLEX'
		, 'TRIPLEX'
		, 'QUADPLEX'
		, 'MOBILE HOME'
		)
        
    GROUP BY 1,2,3,4,5,6
)

SELECT *
FROM recents

UNION -- drop duplicates, in case there are any

SELECT *
FROM historicals

ORDER BY 1, 2 DESC
;
'''

# %%
assessments = pd.read_sql(assessments_query, con = engine)

# %%
assessments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1537895 entries, 0 to 1537894
# Data columns (total 7 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   apn         1537895 non-null  object
#  1   date        1537894 non-null  object
#  2   prop_type   1537895 non-null  object
#  3   prop_addr   1537895 non-null  object
#  4   prop_city   1537895 non-null  object
#  5   prop_zip    1537895 non-null  int64
#  6   prop_value  1537894 non-null  float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 82.1+ MB

# %%
assessments.head()
# Out:
#            apn        date      prop_type              prop_addr  \
# 0  00200000100  2021-01-01  SINGLE FAMILY      1005 HIGHLAND AVE
# 1  00200000100  2017-01-01  SINGLE FAMILY      1005 HIGHLAND AVE
# 2  00200000300  2021-01-01  SINGLE FAMILY  1012 OLD BUCK HILL RD
# 3  00200000300  2017-01-01  SINGLE FAMILY  1012 OLD BUCK HILL RD
# 4  00200000300  2013-01-01  SINGLE FAMILY  1012 OLD BUCK HILL RD
#
#         prop_city  prop_zip  prop_value
# 0  GOODLETTSVILLE     37072         0.0
# 1  GOODLETTSVILLE     37072         0.0
# 2  GOODLETTSVILLE     37072    198400.0
# 3  GOODLETTSVILLE     37072    135400.0
# 4  GOODLETTSVILLE     37072    114000.0

# %% [markdown]
# ### Manually create means of assessments on same date
# #### Delete once this problem is solved by SQL query

# %%
assessment_means = assessments.groupby([
    'apn', 'date', 'prop_type', 'prop_addr', 'prop_city', 'prop_zip'])['prop_value'].mean().reset_index()
assessment_means
# Out:
#                     apn        date          prop_type              prop_addr  \
# 0           00200000100  2017-01-01      SINGLE FAMILY      1005 HIGHLAND AVE
# 1           00200000100  2021-01-01      SINGLE FAMILY      1005 HIGHLAND AVE
# 2           00200000300  1993-01-01      SINGLE FAMILY  1012 OLD BUCK HILL RD
# 3           00200000300  1997-01-01      SINGLE FAMILY  1012 OLD BUCK HILL RD
# 4           00200000300  2001-01-01      SINGLE FAMILY  1012 OLD BUCK HILL RD
# ...                 ...         ...                ...                    ...
# 1537576  188100G00200CO  2021-01-01  RESIDENTIAL CONDO    2000 B OAK TRAIL DR
# 1537577  188100G00300CO  2018-01-01  RESIDENTIAL CONDO    2000 C OAK TRAIL DR
# 1537578  188100G00300CO  2020-01-01  RESIDENTIAL CONDO    2000 C OAK TRAIL DR
# 1537579  188100G00300CO  2020-03-01  RESIDENTIAL CONDO    2000 C OAK TRAIL DR
# 1537580  188100G00300CO  2021-01-01  RESIDENTIAL CONDO    2000 C OAK TRAIL DR
#
#               prop_city  prop_zip  prop_value
# 0        GOODLETTSVILLE     37072         0.0
# 1        GOODLETTSVILLE     37072         0.0
# 2        GOODLETTSVILLE     37072     64550.0
# 3        GOODLETTSVILLE     37072     92400.0
# 4        GOODLETTSVILLE     37072    102400.0
# ...                 ...       ...         ...
# 1537576     NOLENSVILLE     37135    331200.0
# 1537577     NOLENSVILLE     37135     33000.0
# 1537578     NOLENSVILLE     37135    221700.0
# 1537579     NOLENSVILLE     37135    284050.0
# 1537580     NOLENSVILLE     37135    334100.0
#
# [1537581 rows x 7 columns]

# %%
permits_query = '''
-- query to get all historical assessments for residences in Davidson county since 1993
WITH first_assessment AS (-- get historical assessment data for each property when it was residential 
	SELECT a.apn
		, MIN(a.effectivedate) AS date

	FROM assessment AS a
	LEFT JOIN property AS p
		ON p.apn = a.apn
	LEFT JOIN property_updated AS pu
		ON pu.apn = a.apn
	
	WHERE a.classdesc = 'RESIDENTIAL' -- only get assessment data for properties when they were classified as residential
		AND a.effectivedate >= DATE('1993-01-01') -- only get data starting in 1993, when assessments regularized to every 4 years
		AND (-- only get apns that were counted as some form of residential property in 2017 or 2020;
			-- there are no apns that had more than one ludesc in either table, but a handful do change between tables
			p.ludesc IN (
				'SINGLE FAMILY'
				, 'RESIDENTIAL CONDO'
				, 'DUPLEX'
				, 'TRIPLEX'
				, 'QUADPLEX'
				, 'MOBILE HOME'
				)
			OR pu.ludesc IN (
				'SINGLE FAMILY'
				, 'RESIDENTIAL CONDO'
				, 'DUPLEX'
				, 'TRIPLEX'
				, 'QUADPLEX'
				, 'MOBILE HOME'
				)
			)
	
	GROUP BY 1
)

SELECT p.*

FROM permit AS p

JOIN first_assessment AS fa
	ON p.apn = fa.apn
	AND p.dateissued >= fa.date -- only get permits from on or after the first assessment date or 1993-01-01
;
'''

# %%
permits = pd.read_sql(permits_query, con = engine)

# %%
permits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 694648 entries, 0 to 694647
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   permitnumber   694648 non-null  object
#  1   permittype     694648 non-null  object
#  2   permitsubtype  574731 non-null  object
#  3   dateissued     694648 non-null  object
#  4   location       694647 non-null  object
#  5   purpose        594291 non-null  object
#  6   contractor     692300 non-null  object
#  7   value          370519 non-null  object
#  8   status         694648 non-null  object
#  9   pid            694648 non-null  object
#  10  apn            694648 non-null  object
# dtypes: object(11)
# memory usage: 58.3+ MB

# %%
permits.head()
# Out:
#   permitnumber                 permittype           permitsubtype  dateissued  \
# 0    200509325      CODES PLUMBING PERMIT         PLUMBING PERMIT  2005-11-10
# 1    200508249  GAS / MECH PERMIT - VC MC       GAS / MECH PERMIT  2005-11-07
# 2    200508070  GAS / MECH PERMIT - VC MC       GAS / MECH PERMIT  2005-11-02
# 3    200511471          ELECTRICAL PERMIT  FULL ELECTRICAL PERMIT  2005-07-28
# 4    200511472          ELECTRICAL PERMIT  FULL ELECTRICAL PERMIT  2005-07-28
#
#                location purpose                       contractor value  \
# 0  927 BATTERY LN 37220    None  Pc06227: Fred's Plumbing Repair  None
# 1  927 BATTERY LN 37220    None     Vc00317: Hearth & Grill Shop  None
# 2  927 BATTERY LN 37220    None   Vc00233: Bradley Heating & Air  None
# 3  927 BATTERY LN 37220    None          Dc00481: Jones Electric  None
# 4  927 BATTERY LN 37220    None          Dc00481: Jones Electric  None
#
#     status      pid          apn
# 0     DONE  1299272  13209012400
# 1  EXPIRED  1074966  13209012400
# 2  EXPIRED  1070903  13209012400
# 3     DONE   916358  13209012400
# 4     DONE   916359  13209012400

# %% [markdown]
# *The following query just returns a list of APNs and every assessment / permit pulled with date over the lifetime of a property (since 1993 or first residential assessment).*

# %%
p_and_a_per_apn_query = '''
-- query to get a lifetime history for each house since 1993
-- not particularly efficient...
WITH historicals AS (-- get historical assessment data for each property when it was residential 
	SELECT a.apn
		, a.effectivedate AS date
		, 'assessment' AS permit_num

	FROM assessment AS a
	LEFT JOIN property AS p
		ON p.apn = a.apn
	LEFT JOIN property_updated AS pu
		ON pu.apn = a.apn
	
	WHERE a.classdesc = 'RESIDENTIAL' -- only get assessment data for properties when they were classified as residential
		AND a.effectivedate >= DATE('1993-01-01') -- only get data starting in 1993, when assessments regularized to every 4 years
		AND (-- only get apns that were counted as some form of residential property in 2017 or 2020;
			-- there are no apns that had more than one ludesc in either table, but a handful do change between tables
			p.ludesc IN (
				'SINGLE FAMILY'
				, 'RESIDENTIAL CONDO'
				, 'DUPLEX'
				, 'TRIPLEX'
				, 'QUADPLEX'
				, 'MOBILE HOME'
				)
			OR pu.ludesc IN (
				'SINGLE FAMILY'
				, 'RESIDENTIAL CONDO'
				, 'DUPLEX'
				, 'TRIPLEX'
				, 'QUADPLEX'
				, 'MOBILE HOME'
				)
			)
),

recents AS (-- get address and property type info for 2021 and any non-overlapping 2017 apns
	SELECT pu.apn
		, pu.assessdate AS date
		, 'assessment' AS permit_num
	
	FROM property_updated AS pu
	
	WHERE pu.ludesc IN (
		'SINGLE FAMILY'
		, 'RESIDENTIAL CONDO'
		, 'DUPLEX'
		, 'TRIPLEX'
		, 'QUADPLEX'
		, 'MOBILE HOME'
		)
	
	UNION -- drop duplicate rows, just in case they sneak in
	
	SELECT p.apn
		, p.assessdate AS date
		, 'assessment' AS permit_num
	
	FROM property AS p
	
	WHERE p.ludesc IN (
		'SINGLE FAMILY'
		, 'RESIDENTIAL CONDO'
		, 'DUPLEX'
		, 'TRIPLEX'
		, 'QUADPLEX'
		, 'MOBILE HOME'
		)
),

assessments AS (
	SELECT *
	FROM recents

	UNION -- drop duplicates, in case there are any

	SELECT *
	FROM historicals
),

permits AS (
	WITH first_assessment AS (-- get historical assessment data for each property when it was residential 
		SELECT a.apn
			, MIN(a.effectivedate) AS date

		FROM assessment AS a
		LEFT JOIN property AS p
			ON p.apn = a.apn
		LEFT JOIN property_updated AS pu
			ON pu.apn = a.apn

		WHERE a.classdesc = 'RESIDENTIAL' -- only get assessment data for properties when they were classified as residential
			AND a.effectivedate >= DATE('1993-01-01') -- only get data starting in 1993, when assessments regularized to every 4 years
			AND (-- only get apns that were counted as some form of residential property in 2017 or 2020;
				-- there are no apns that had more than one ludesc in either table, but a handful do change between tables
				p.ludesc IN (
					'SINGLE FAMILY'
					, 'RESIDENTIAL CONDO'
					, 'DUPLEX'
					, 'TRIPLEX'
					, 'QUADPLEX'
					, 'MOBILE HOME'
					)
				OR pu.ludesc IN (
					'SINGLE FAMILY'
					, 'RESIDENTIAL CONDO'
					, 'DUPLEX'
					, 'TRIPLEX'
					, 'QUADPLEX'
					, 'MOBILE HOME'
					)
				)

		GROUP BY 1
	)

	SELECT p.apn
		, p.dateissued AS date
		, p.permitnumber AS permit_num

	FROM permit AS p

	JOIN first_assessment AS fa
		ON p.apn = fa.apn
		AND p.dateissued >= fa.date -- only get permits from on or after the first assessment date or 1993-01-01
)

SELECT *
FROM assessments

UNION ALL -- ever so slightly faster than UNION and no need to dedupe

SELECT *
FROM permits

ORDER BY 1,2 DESC
;
'''

# %%
p_and_a_per_apn = pd.read_sql(p_and_a_per_apn_query, con = engine)

# %%
p_and_a_per_apn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2232230 entries, 0 to 2232229
# Data columns (total 3 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   apn         object
#  1   date        object
#  2   permit_num  object
# dtypes: object(3)
# memory usage: 51.1+ MB

# %%
p_and_a_per_apn.head()
# Out:
#            apn        date  permit_num
# 0  00200000100  2021-01-01  assessment
# 1  00200000100  2017-01-01  assessment
# 2  00200000300  2021-01-01  assessment
# 3  00200000300  2017-01-01  assessment
# 4  00200000300  2013-01-01  assessment

# %% [markdown]
# *Weirdly enough, there appear to be about 50K assessments that go missing when we only pull APN and date; should investigate why and what might be causing duplication in the `assessments` query above.*

# %%
p_and_a_per_apn[p_and_a_per_apn['permit_num'] == 'assessment'].count()
# Out:
# apn           1537582
# date          1537581
# permit_num    1537582
# dtype: int64

# %%
p_and_a_per_apn['permit_num'].value_counts()
# Out:
# assessment    1537582
# 200600031           5
# 199707545           5
# 199706157           5
# 200102265           5
#                ...
# 201236200           1
# 200204171           1
# 2021003297          1
# 2016053548          1
# 2019019484          1
# Name: permit_num, Length: 528066, dtype: int64

# %% [markdown]
# ## Begin Parker Exploring
# ### When ready, export dataframes as CSVs, and move below into mp_02 feature engineering.

# %%
assessment_means.head(5)
# Out:
#            apn        date      prop_type              prop_addr  \
# 0  00200000100  2017-01-01  SINGLE FAMILY      1005 HIGHLAND AVE
# 1  00200000100  2021-01-01  SINGLE FAMILY      1005 HIGHLAND AVE
# 2  00200000300  1993-01-01  SINGLE FAMILY  1012 OLD BUCK HILL RD
# 3  00200000300  1997-01-01  SINGLE FAMILY  1012 OLD BUCK HILL RD
# 4  00200000300  2001-01-01  SINGLE FAMILY  1012 OLD BUCK HILL RD
#
#         prop_city  prop_zip  prop_value
# 0  GOODLETTSVILLE     37072         0.0
# 1  GOODLETTSVILLE     37072         0.0
# 2  GOODLETTSVILLE     37072     64550.0
# 3  GOODLETTSVILLE     37072     92400.0
# 4  GOODLETTSVILLE     37072    102400.0

# %%
permits.head(5)
# Out:
#   permitnumber                 permittype           permitsubtype  dateissued  \
# 0    200509325      CODES PLUMBING PERMIT         PLUMBING PERMIT  2005-11-10
# 1    200508249  GAS / MECH PERMIT - VC MC       GAS / MECH PERMIT  2005-11-07
# 2    200508070  GAS / MECH PERMIT - VC MC       GAS / MECH PERMIT  2005-11-02
# 3    200511471          ELECTRICAL PERMIT  FULL ELECTRICAL PERMIT  2005-07-28
# 4    200511472          ELECTRICAL PERMIT  FULL ELECTRICAL PERMIT  2005-07-28
#
#                location purpose                       contractor value  \
# 0  927 BATTERY LN 37220    None  Pc06227: Fred's Plumbing Repair  None
# 1  927 BATTERY LN 37220    None     Vc00317: Hearth & Grill Shop  None
# 2  927 BATTERY LN 37220    None   Vc00233: Bradley Heating & Air  None
# 3  927 BATTERY LN 37220    None          Dc00481: Jones Electric  None
# 4  927 BATTERY LN 37220    None          Dc00481: Jones Electric  None
#
#     status      pid          apn
# 0     DONE  1299272  13209012400
# 1  EXPIRED  1074966  13209012400
# 2  EXPIRED  1070903  13209012400
# 3     DONE   916358  13209012400
# 4     DONE   916359  13209012400

# %% [markdown]
# ## Verification

# %%
#Count number of unique apns on assessments
print(assessments['apn'].nunique())
# Out:
# 210448

# %%
#Count number of unique APNs with permits
permits['apn'].nunique()
# Out:
# 148687

# %%
#Find houses with a permit, but no assessment
assessments_apn_list = assessments['apn'].to_list()

# %%
len(permits[~permits['apn'].isin(assessments_apn_list)]['apn'])
# Out:
# 0

# %%
#Find houses with multiple assessments on the same date
assessment_count = assessments.groupby(['apn', 'date'])['prop_value'].count()

# %%
assessment_count = assessment_count.reset_index().sort_values(by = 'prop_value', ascending=False)

# %%
assessment_count[assessment_count['prop_value'] > 1]
# Out:
#                     apn        date  prop_value
# 18116       01800015800  2019-01-01           2
ERMIT)   HEREBY CERTIFY THAT ALL CONSTRUCTION AND DEMOLITION WASTE GENERATED BY ANY AND ALL ACTIVITIES GOVERNED BY THIS PERMIT SHALL BE DISPOSED OF IN AN APPROVED LANDFILL.   FURTHER, I CERTIFY THAT NO CONSTRUCTION AND DEMOLITION WASTE SHALL BE STORED ON THE PROPERTY IN VIOLATION OF ANY PROVISION OF THE METROPOLITAN CODE….\n\n
# 616434                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ACTIVITY-TYPE: A01 PURPOSE: TO CONSTRUCT A NEW ATTACHED 28 X 14 CARPORT TO SIDE OF RESIDENCE. FRONT STBK MIN 24'. NOT TO BE OVER ANY EASEMENTS. BZA: SIDE STBK REQUIRED 5'. REQUEST 3'. VARIANCE OF 2' CARPORT MUST REMAIN OPEN.
# 616435                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ACTIVITY-TYPE: A02 DESIGNER: **IN RT'S FILE. PURPOSE: TO INSTALL A NEW 28X64 MODULAR RESIDENCE. FRONT STBK-24' BASED ON ST BLOCK AVERAGE. . SIDES-11' FRONT/REAR FACADE FACES SIDE LOT LINES. REAR-20', IN FILE SETTLEMENT STATEMENT AND TITLE PAPERS SHOWING MARY COVINGTON AS OWNER. STRRET BLOCK CHECKED BY J.P. PAPERWORK SENT TO M/P FILES 12/20/96
# 616436                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ACTIVITY-TYPE: A02 DESIGNER: **IN RT'S FILE. PURPOSE: TO INSTALL A NEW 28X64 MODULAR RESIDENCE. FRONT STBK-24' BASED ON ST BLOCK AVERAGE. . SIDES-11' FRONT/REAR FACADE FACES SIDE LOT LINES. REAR-20', IN FILE SETTLEMENT STATEMENT AND TITLE PAPERS SHOWING MARY COVINGTON AS OWNER. STRRET BLOCK CHECKED BY J.P. PAPERWORK SENT TO M/P FILES 12/20/96
# 616437                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ACTIVITY-TYPE: A02 DESIGNER: **IN RT'S FILE. PURPOSE: TO INSTALL A NEW 28X64 MODULAR RESIDENCE. FRONT STBK-24' BASED ON ST BLOCK AVERAGE. . SIDES-11' FRONT/REAR FACADE FACES SIDE LOT LINES. REAR-20', IN FILE SETTLEMENT STATEMENT AND TITLE PAPERS SHOWING MARY COVINGTON AS OWNER. STRRET BLOCK CHECKED BY J.P. PAPERWORK SENT TO M/P FILES 12/20/96
# 616438                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ACTIVITY-TYPE: A02 PURPOSE: TO DEMOLISH REMAINDER OF EXISTING FIRE DAMAGED RESIDENCE. (NOT TO BE BURNED OR BURIED ON LOT) DEMO BY 4/28/94 HOUSING APPROVED: ANN STONE 3/28/94 WCA
#
#                                    contractor     value   status      pid  \
# 616422              Reliance Heating & Air Co    3000.0     DONE  1929850
# 616423          Modern Mechanical Contractors       0.0     DONE  1929808
# 616424          Modern Mechanical Contractors       0.0     DONE  1929802
# 616425                      R & W Home Repair    7800.0  EXPIRED  1700764
# 616426                 Benchmark Plumbing Inc    5000.0     DONE  1923268
# 616427              Reliance Heating & Air Co    9500.0     DONE  1913398
# 616428                 Benchmark Plumbing Inc    9000.0     DONE  1913306
# 616429          Modern Mechanical Contractors       0.0     DONE  1913172
# 616430          Modern Mechanical Contractors       7.0     DONE  1913170
# 616431          Modern Mechanical Contractors       0.0     DONE  1907601
# 616432              Palmetto Construction Llc  296661.0     DONE  1905888
# 616433              Palmetto Construction Llc   74481.0     DONE  1905910
# 616434  Gc10237: Protech Home Improvement Llc    4706.0     DONE  1373806
# 616435      Pc00190: Brooks, W M Plumbing Inc      None     DONE  1213985
# 616436  Ec08959: Borders Electric Service Inc      None     DONE   743330
# 616437                      Covington, Mary E   98560.0     DONE  1368527
# 616438            Gc07425: Lewis, David Contr    4000.0     DONE   474015
#
#                 apn
# 616422  11704019300
# 616423  11704019300
# 616424  11704019300
# 616425  11704019300
# 616426  11704019300
# 616427  11704019300
# 616428  11704019300
# 616429  11704019300
# 616430  11704019300
# 616431  11704019300
# 616432  11704019300
# 616433  11704019300
# 616434  11704019300
# 616435  11704019300
# 616436  11704019300
# 616437  11704019300
# 616438  11704019300

# %%
check_assessments_query = '''
SELECT *
FROM assessment
WHERE apn = '11704019300'
'''

# %%
check_assessments = pd.read_sql(check_assessments_query, con = engine)
check_assessments
# Out:
#    class    classdesc  classvalue effectivedate  landapprvalue  \
# 0      R  RESIDENTIAL          25    2013-09-01         180000
# 1      R  RESIDENTIAL          25    2013-01-01         180000
# 2      R  RESIDENTIAL          25    2010-01-01         195400
# 3      R  RESIDENTIAL          25    2009-01-01         195400
# 4      R  RESIDENTIAL          25    2009-01-01         150000
# 5      R  RESIDENTIAL          25    2009-01-01         150000
# 6      R  RESIDENTIAL          25    2005-01-01          80000
# 7      R  RESIDENTIAL          25    2005-01-01          80000
# 8      R  RESIDENTIAL          25    2005-01-01          80000
# 9      R  RESIDENTIAL          25    2002-01-01          45000
# 10     R  RESIDENTIAL          25    2001-01-01          45000
# 11     R  RESIDENTIAL          25    2001-01-01          45000
# 12     R  RESIDENTIAL          25    2001-01-01          45000
# 13     R  RESIDENTIAL          25    2001-01-01          45000
# 14     R  RESIDENTIAL          25    1997-01-01          45000
# 15     R  RESIDENTIAL          25    1997-01-01          45000
# 16     R  RESIDENTIAL          25    1997-01-01          45000
# 17     R  RESIDENTIAL          25    1996-01-01          22500
# 18     R  RESIDENTIAL          25    1996-01-01          22500
# 19     R  RESIDENTIAL          25    1994-06-01          22500
# 20     R  RESIDENTIAL          25    1994-01-01          22500
# 21     R  RESIDENTIAL          25    1993-01-01          22500
# 22     R  RESIDENTIAL          25    1989-01-01          10000
# 23     R  RESIDENTIAL          25    1984-01-01          10000
# 24     R  RESIDENTIAL          25    1975-01-01           2360
#
#     improveapprvalue  landassessvalue  improveassessvalue  totalapprvalue  \
# 0             473100           653100               45000          653100
# 1                  0           180000               45000          180000
# 2              10000           205400               48850          205400
# 3              10000           205400               48850          205400
# 4              83200           233200               37500          233200
# 5              55400           205400               37500          205400
# 6              70000           150000               20000          150000
# 7              70000           150000               20000          150000
# 8             133800           213800               20000          213800
# 9              60000           105000               11250          105000
# 10             60000           105000               11250          105000
# 11             67000           112000               11250          112000
# 12             87900           132900               11250          132900
# 13            106400           151400               11250          151400
# 14             42300            87300               11250           87300
# 15             42300            87300               11250           87300
# 16             87900           132900               11250          132900
# 17             53700            76200                5625           76200
# 18             42500            65000                5625           65000
# 19                 0            22500                5625           22500
# 20              1000            23500                5625           23500
# 21             54100            76600                5625           76600
